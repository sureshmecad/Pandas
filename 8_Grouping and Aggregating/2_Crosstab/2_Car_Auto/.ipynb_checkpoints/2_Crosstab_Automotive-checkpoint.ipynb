# %% [markdown]
# https://pbpython.com/pandas-crosstab.html

# %% [markdown]
# ## Crosstab

# %% [markdown]
# - **Crosstab (also known as contingency table or cross tabulation)** is a table showing frequency distribution of one variable in rows and another on columns. pandas crosstab method can be used to generate these contingency tables that are extremely useful in survey and business analytics.

# %% [markdown]
# ![2_Car_Auto](image/1.JPG)

# %% [markdown]
# -------------------

# %% [markdown]
# ![2_Car_Auto](image/2.JPG)

# %% [markdown]
# ---------------

# %%
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
# Define the headers since the data does not have any
headers = ["symboling", "normalized_losses", "make", "fuel_type", "aspiration",
           "num_doors", "body_style", "drive_wheels", "engine_location",
           "wheel_base", "length", "width", "height", "curb_weight",
           "engine_type", "num_cylinders", "engine_size", "fuel_system",
           "bore", "stroke", "compression_ratio", "horsepower", "peak_rpm",
           "city_mpg", "highway_mpg", "price"]

# %%
# Read in the CSV file and convert "?" to NaN
df_raw = pd.read_csv("imports-85.data.csv", header=None, names=headers, na_values="?" )
df_raw.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration num_doors  \
# 0          3                NaN  alfa-romero       gas        std       two
# 1          3                NaN  alfa-romero       gas        std       two
# 2          1                NaN  alfa-romero       gas        std       two
# 3          2              164.0         audi       gas        std      four
# 4          2              164.0         audi       gas        std      four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 0         mpfi  3.47    2.68               9.0      111.0    5000.0       21
# 1         mpfi  3.47    2.68               9.0      111.0    5000.0       21
# 2         mpfi  2.68    3.47               9.0      154.0    5000.0       19
# 3         mpfi  3.19    3.40              10.0      102.0    5500.0       24
# 4         mpfi  3.19    3.40               8.0      115.0    5500.0       18
#
#    highway_mpg    price
# 0           27  13495.0
# 1           27  16500.0
# 2           26  16500.0
# 3           30  13950.0
# 4           22  17450.0
#
# [5 rows x 26 columns]

# %%
# Filter out the top 8 manufacturers
models = ["toyota","nissan","mazda", "honda", "mitsubishi", "subaru", "volkswagen", "volvo"]

# %%
df = df_raw[df_raw.make.isin(models)].copy()
df.head()
# Out:
#     symboling  normalized_losses   make fuel_type aspiration num_doors  \
# 30          2              137.0  honda       gas        std       two
# 31          2              137.0  honda       gas        std       two
# 32          1              101.0  honda       gas        std       two
# 33          1              101.0  honda       gas        std       two
# 34          1              101.0  honda       gas        std       two
#
#    body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 30  hatchback          fwd           front        86.6  ...           92
# 31  hatchback          fwd           front        86.6  ...           92
# 32  hatchback          fwd           front        93.7  ...           79
# 33  hatchback          fwd           front        93.7  ...           92
# 34  hatchback          fwd           front        93.7  ...           92
#
#     fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 30         1bbl  2.91    3.41               9.6       58.0    4800.0       49
# 31         1bbl  2.91    3.41               9.2       76.0    6000.0       31
# 32         1bbl  2.91    3.07              10.1       60.0    5500.0       38
# 33         1bbl  2.91    3.41               9.2       76.0    6000.0       30
# 34         1bbl  2.91    3.41               9.2       76.0    6000.0       30
#
#     highway_mpg   price
# 30           54  6479.0
# 31           38  6855.0
# 32           42  5399.0
# 33           34  6529.0
# 34           34  7129.0
#
# [5 rows x 26 columns]

# %%
df['num_doors'].value_counts()
# Out:
# four    71
# two     56
# Name: num_doors, dtype: int64

# %%
df['make'].value_counts()
# Out:
# toyota        32
# nissan        18
# mazda         17
# mitsubishi    13
# honda         13
# volkswagen    12
# subaru        12
# volvo         11
# Name: make, dtype: int64

# %%
df['make'].nunique()
# Out:
# 8

# %% [markdown]
# ### This table shows the number of two or four door cars manufactured by various car makers:

# %%
# Create a simple crosstab that counts the number of occurences of each combination
pd.crosstab(df.make, df.num_doors)
# Out:
# num_doors   four  two
# make
# honda          5    8
# mazda          7    9
# mitsubishi     4    9
# nissan         9    9
# subaru         9    3
# toyota        18   14
# volkswagen     8    4
# volvo         11    0

# %%
# Add a subtotal
pd.crosstab(df.make, df.num_doors, margins=True, margins_name="Total")
# Out:
# num_doors   four  two  Total
# make
# honda          5    8     13
# mazda          7    9     16
# mitsubishi     4    9     13
# nissan         9    9     18
# subaru         9    3     12
# toyota        18   14     32
# volkswagen     8    4     12
# volvo         11    0     11
# Total         71   56    127

# %%
pd.crosstab(df.make, df.num_doors, margins=True, margins_name="Total").style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow0_col0 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow0_col1 {
#             background-color:  #dbed66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow0_col2 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow1_col0 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow1_col1 {
#             background-color:  #d6eb66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow1_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow2_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow2_col1 {
#             background-color:  #d6eb66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow2_col2 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow3_col0 {
#             background-color:  #ecf666;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow3_col1 {
#             background-color:  #d6eb66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow3_col2 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow4_col0 {
#             background-color:  #ecf666;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow4_col1 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow4_col2 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow5_col0 {
#             background-color:  #cae466;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow5_col1 {
#             background-color:  #bfdf66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow5_col2 {
#             background-color:  #d1e866;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow6_col0 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow6_col1 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow6_col2 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow7_col0 {
#             background-color:  #e5f266;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow7_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow7_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow8_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow8_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow8_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffa" ><thead>    <tr>        <th class="index_name level0" >num_doors</th>        <th class="col_heading level0 col0" >four</th>        <th class="col_heading level0 col1" >two</th>        <th class="col_heading level0 col2" >Total</th>    </tr>    <tr>        <th class="index_name level0" >make</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffalevel0_row0" class="row_heading level0 row0" >honda</th>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow0_col0" class="data row0 col0" >5</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow0_col1" class="data row0 col1" >8</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow0_col2" class="data row0 col2" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffalevel0_row1" class="row_heading level0 row1" >mazda</th>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow1_col0" class="data row1 col0" >7</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow1_col1" class="data row1 col1" >9</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow1_col2" class="data row1 col2" >16</td>
#             </tr>
#             <tr>
#                         <th id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffalevel0_row2" class="row_heading level0 row2" >mitsubishi</th>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow2_col0" class="data row2 col0" >4</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow2_col1" class="data row2 col1" >9</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow2_col2" class="data row2 col2" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffalevel0_row3" class="row_heading level0 row3" >nissan</th>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow3_col0" class="data row3 col0" >9</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow3_col1" class="data row3 col1" >9</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow3_col2" class="data row3 col2" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffalevel0_row4" class="row_heading level0 row4" >subaru</th>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow4_col0" class="data row4 col0" >9</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow4_col1" class="data row4 col1" >3</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow4_col2" class="data row4 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffalevel0_row5" class="row_heading level0 row5" >toyota</th>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow5_col0" class="data row5 col0" >18</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow5_col1" class="data row5 col1" >14</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow5_col2" class="data row5 col2" >32</td>
#             </tr>
#             <tr>
#                         <th id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffalevel0_row6" class="row_heading level0 row6" >volkswagen</th>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow6_col0" class="data row6 col0" >8</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow6_col1" class="data row6 col1" >4</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow6_col2" class="data row6 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffalevel0_row7" class="row_heading level0 row7" >volvo</th>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow7_col0" class="data row7 col0" >11</td>
#                         <td id="T_974f2ca2_dafc_11ea_98f3_3c77e6dc4ffarow7_col1" class="data row7 col1" >0</td>
#                         <t

# %% [markdown]
# - In the table above, you can see that the data set contains 32 Toyota cars of which 18 are four door and 14 are two door.

# %% [markdown]
# --------------

# %%
# Another example, this time of make and body_style
pd.crosstab(df.make, df.body_style).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow0_col2 {
#             background-color:  #7fbf66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow0_col3 {
#             background-color:  #d5ea66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow0_col4 {
#             background-color:  #bfdf66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow1_col2 {
#             background-color:  #49a466;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow1_col3 {
#             background-color:  #7fbf66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow2_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow2_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow2_col2 {
#             background-color:  #5bad66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow2_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow2_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow3_col1 {
#             background-color:  #aad466;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow3_col2 {
#             background-color:  #a4d266;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow3_col3 {
#             background-color:  #2a9466;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow3_col4 {
#             background-color:  #3f9f66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow4_col2 {
#             background-color:  #c9e466;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow4_col3 {
#             background-color:  #d5ea66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow4_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow5_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow5_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow5_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow5_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow5_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow6_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow6_col2 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow6_col3 {
#             background-color:  #2a9466;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow6_col4 {
#             background-color:  #bfdf66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow7_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow7_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow7_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow7_col3 {
#             background-color:  #55aa66;
#             color:  #000000;
#         }    #T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow7_col4 {
#             background-color:  #3f9f66;
#             color:  #000000;
#         }</style><table id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffa" ><thead>    <tr>        <th class="index_name level0" >body_style</th>        <th class="col_heading level0 col0" >convertible</th>        <th class="col_heading level0 col1" >hardtop</th>        <th class="col_heading level0 col2" >hatchback</th>        <th class="col_heading level0 col3" >sedan</th>        <th class="col_heading level0 col4" >wagon</th>    </tr>    <tr>        <th class="index_name level0" >make</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffalevel0_row0" class="row_heading level0 row0" >honda</th>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow0_col2" class="data row0 col2" >7</td>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow0_col3" class="data row0 col3" >5</td>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow0_col4" class="data row0 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffalevel0_row1" class="row_heading level0 row1" >mazda</th>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow1_col1" class="data row1 col1" >0</td>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow1_col2" class="data row1 col2" >10</td>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow1_col3" class="data row1 col3" >7</td>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow1_col4" class="data row1 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffalevel0_row2" class="row_heading level0 row2" >mitsubishi</th>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow2_col0" class="data row2 col0" >0</td>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow2_col1" class="data row2 col1" >0</td>
#                         <td id="T_399f0de8_daff_11ea_94c6_3c77e6dc4ffarow2_col2" class="data row2 col2" >9</td>
#                         <td id="T_399f0de8_daff_11ea_9

# %%
# Add custom names for the rows and columns?
pd.crosstab(df.make, df.body_style, rownames=['Auto Manufacturer'], colnames=['Body Style'])
# Out:
# Body Style         convertible  hardtop  hatchback  sedan  wagon
# Auto Manufacturer
# honda                        0        0          7      5      1
# mazda                        0        0         10      7      0
# mitsubishi                   0        0          9      4      0
# nissan                       0        1          5      9      3
# subaru                       0        0          3      5      4
# toyota                       1        3         14     10      4
# volkswagen                   1        0          1      9      1
# volvo                        0        0          0      8      3

# %%
# Convert the occurrences to percentages
pd.crosstab(df.make, df.body_style, normalize=True)
# Out:
# body_style  convertible   hardtop  hatchback     sedan     wagon
# make
# honda          0.000000  0.000000   0.054688  0.039062  0.007812
# mazda          0.000000  0.000000   0.078125  0.054688  0.000000
# mitsubishi     0.000000  0.000000   0.070312  0.031250  0.000000
# nissan         0.000000  0.007812   0.039062  0.070312  0.023438
# subaru         0.000000  0.000000   0.023438  0.039062  0.031250
# toyota         0.007812  0.023438   0.109375  0.078125  0.031250
# volkswagen     0.007812  0.000000   0.007812  0.070312  0.007812
# volvo          0.000000  0.000000   0.000000  0.062500  0.023438

# %%
# Convert the occurrences to percentages for each row
pd.crosstab(df.make, df.body_style, normalize='index')
# Out:
# body_style  convertible   hardtop  hatchback     sedan     wagon
# make
# honda          0.000000  0.000000   0.538462  0.384615  0.076923
# mazda          0.000000  0.000000   0.588235  0.411765  0.000000
# mitsubishi     0.000000  0.000000   0.692308  0.307692  0.000000
# nissan         0.000000  0.055556   0.277778  0.500000  0.166667
# subaru         0.000000  0.000000   0.250000  0.416667  0.333333
# toyota         0.031250  0.093750   0.437500  0.312500  0.125000
# volkswagen     0.083333  0.000000   0.083333  0.750000  0.083333
# volvo          0.000000  0.000000   0.000000  0.727273  0.272727

# %%
# Convert the occurrences to percentages for each column
pd.crosstab(df.make, df.body_style, normalize='columns')
# Out:
# body_style  convertible  hardtop  hatchback     sedan   wagon
# make
# honda               0.0     0.00   0.142857  0.087719  0.0625
# mazda               0.0     0.00   0.204082  0.122807  0.0000
# mitsubishi          0.0     0.00   0.183673  0.070175  0.0000
# nissan              0.0     0.25   0.102041  0.157895  0.1875
# subaru              0.0     0.00   0.061224  0.087719  0.2500
# toyota              0.5     0.75   0.285714  0.175439  0.2500
# volkswagen          0.5     0.00   0.020408  0.157895  0.0625
# volvo               0.0     0.00   0.000000  0.140351  0.1875

# %%
# If you want to make the percentages a little easier to see, multiple all values by 100
pd.crosstab(df.make, df.body_style, normalize='columns').mul(100).round(0)
# Out:
# body_style  convertible  hardtop  hatchback  sedan  wagon
# make
# honda               0.0      0.0       14.0    9.0    6.0
# mazda               0.0      0.0       20.0   12.0    0.0
# mitsubishi          0.0      0.0       18.0    7.0    0.0
# nissan              0.0     25.0       10.0   16.0   19.0
# subaru              0.0      0.0        6.0    9.0   25.0
# toyota             50.0     75.0       29.0   18.0   25.0
# volkswagen         50.0      0.0        2.0   16.0    6.0
# volvo               0.0      0.0        0.0   14.0   19.0

# %% [markdown]
# ### Custom Aggregations and Grouping

# %%
# Perform aggregation functions - not just a simple count
pd.crosstab(df.make, df.body_style, values=df.curb_weight, aggfunc='mean').round(0)
# Out:
# body_style  convertible  hardtop  hatchback   sedan   wagon
# make
# honda               NaN      NaN     1970.0  2289.0  2024.0
# mazda               NaN      NaN     2254.0  2361.0     NaN
# mitsubishi          NaN      NaN     2377.0  2394.0     NaN
# nissan              NaN   2008.0     2740.0  2238.0  2452.0
# subaru              NaN      NaN     2137.0  2314.0  2454.0
# toyota           2975.0   2585.0     2370.0  2338.0  2708.0
# volkswagen       2254.0      NaN     2221.0  2342.0  2563.0
# volvo               NaN      NaN        NaN  3023.0  3078.0

# %%
pd.crosstab(df.make, [df.body_style, df.drive_wheels], values=df.curb_weight, aggfunc='mean').fillna('-')
# Out:
# body_style   convertible       hardtop       hatchback                    \
# drive_wheels         fwd   rwd     fwd   rwd       4wd      fwd      rwd
# make
# honda                  -     -       -     -         -     1970        -
# mazda                  -     -       -     -         -  2148.33  2411.25
# mitsubishi             -     -       -     -         -  2376.56        -
# nissan                 -     -    2008     -         -     2176  3116.33
# subaru                 -     -       -     -      2240     2085        -
# toyota                 -  2975       -  2585         -  2177.25  2626.83
# volkswagen          2254     -       -     -         -     2221        -
# volvo                  -     -       -     -         -        -        -
#
# body_style     sedan                   wagon
# drive_wheels     4wd      fwd      rwd   4wd      fwd      rwd
# make
# honda              -   2288.8        -     -     2024        -
# mazda              -   2231.6     2685     -        -        -
# mitsubishi         -     2394        -     -        -        -
# nissan             -  2237.89        -     -  2452.33        -
# subaru        2447.5     2225        -  2535   2372.5        -
# toyota             -  2258.57  2521.67  2700     2280     3151
# volkswagen         -  2342.22        -     -     2563        -
# volvo              -        -     3023     -        -  3077.67

# %%
# Crosstab supports grouping as well. In this case, group the columns
pd.crosstab(df.make, [df.body_style, df.drive_wheels])
# Out:
# body_style   convertible     hardtop     hatchback         sedan          \
# drive_wheels         fwd rwd     fwd rwd       4wd fwd rwd   4wd fwd rwd
# make
# honda                  0   0       0   0         0   7   0     0   5   0
# mazda                  0   0       0   0         0   6   4     0   5   2
# mitsubishi             0   0       0   0         0   9   0     0   4   0
# nissan                 0   0       1   0         0   2   3     0   9   0
# subaru                 0   0       0   0         1   2   0     2   3   0
# toyota                 0   1       0   3         0   8   6     0   7   3
# volkswagen             1   0       0   0         0   1   0     0   9   0
# volvo                  0   0       0   0         0   0   0     0   0   8
#
# body_style   wagon
# drive_wheels   4wd fwd rwd
# make
# honda            0   1   0
# mazda            0   0   0
# mitsubishi       0   0   0
# nissan           0   3   0
# subaru           2   2   0
# toyota           2   1   1
# volkswagen       0   1   0
# volvo            0   0   3

# %%
# A more complex example showing the grouping of rows and columns
pd.crosstab([df.make, df.num_doors], [df.body_style, df.drive_wheels], 
            rownames=['Auto Manufacturer', "Doors"], 
            colnames=['Body Style', "Drive Type"], 
            dropna=False)
# Out:
# Body Style              convertible         hardtop         hatchback          \
# Drive Type                      4wd fwd rwd     4wd fwd rwd       4wd fwd rwd
# Auto Manufacturer Doors
# honda             four            0   0   0       0   0   0         0   0   0
#                   two             0   0   0       0   0   0         0   7   0
# mazda             four            0   0   0       0   0   0         0   1   0
#                   two             0   0   0       0   0   0         0   5   4
# mitsubishi        four            0   0   0       0   0   0         0   0   0
#                   two             0   0   0       0   0   0         0   9   0
# nissan            four            0   0   0       0   0   0         0   1   0
#                   two             0   0   0       0   1   0         0   1   3
# subaru            four            0   0   0       0   0   0         0   0   0
#                   two             0   0   0       0   0   0         1   2   0
# toyota            four            0   0   0       0   0   0         0   6   0
#                   two             0   0   1       0   0   3         0   2   6
# volkswagen        four            0   0   0       0   0   0         0   0   0
#                   two             0   1   0       0   0   0         0   1   0
# volvo             four            0   0   0       0   0   0         0   0   0
#                   two             0   0   0       0   0   0         0   0   0
#
# Body Style              sedan         wagon
# Drive Type                4wd fwd rwd   4wd fwd rwd
# Auto Manufacturer Doors
# honda             four      0   4   0     0   1   0
#                   two       0   1   0     0   0   0
# mazda             four      0   4   2     0   0   0
#                   two       0   0   0     0   0   0
# mitsubishi        four      0   4   0     0   0   0
#                   two       0   0   0     0   0   0
# nissan            four      0   5   0     0   3   0
#                   two       0   4   0     0   0   0
# subaru            four      2   3   0     2   2   0
#                   two       0   0   0     0   0   0
# toyota            four      0   7   1     2   1   1
#                   two       0   0   2     0   0   0
# volkswagen        four      0   7   0     0   1   0
#                   two       0   2   0     0   0   0
# volvo             four      0   0   8     0   0   3
#                   two       0   0   0     0   0   0

# %%
# You can also use agg functions when grouping
pd.crosstab(df.make, [df.body_style, df.drive_wheels], values=df.curb_weight, aggfunc='mean').fillna('-')
# Out:
# body_style   convertible       hardtop       hatchback                    \
# drive_wheels         fwd   rwd     fwd   rwd       4wd      fwd      rwd
# make
# honda                  -     -       -     -         -     1970        -
# mazda                  -     -       -     -         -  2148.33  2411.25
# mitsubishi             -     -       -     -         -  2376.56        -
# nissan                 -     -    2008     -         -     2176  3116.33
# subaru                 -     -       -     -      2240     2085        -
# toyota                 -  2975       -  2585         -  2177.25  2626.83
# volkswagen          2254     -       -     -         -     2221        -
# volvo                  -     -       -     -         -        -        -
#
# body_style     sedan                   wagon
# drive_wheels     4wd      fwd      rwd   4wd      fwd      rwd
# make
# honda              -   2288.8        -     -     2024        -
# mazda              -   2231.6     2685     -        -        -
# mitsubishi         -     2394        -     -        -        -
# nissan             -  2237.89        -     -  2452.33        -
# subaru        2447.5     2225        -  2535   2372.5        -
# toyota             -  2258.57  2521.67  2700     2280     3151
# volkswagen         -  2342.22        -     -     2563        -
# volvo              -        -     3023     -        -  3077.67

# %%
# You can also use margins when grouping
pd.crosstab(df.make, [df.body_style, df.drive_wheels], 
            values=df.curb_weight, aggfunc='mean', margins=True,
            margins_name='Average').fillna('-').round(0)
# Out:
# body_style   convertible       hardtop       hatchback                    \
# drive_wheels         fwd   rwd     fwd   rwd       4wd      fwd      rwd
# make
# honda                  -     -       -     -         -     1970        -
# mazda                  -     -       -     -         -  2148.33  2411.25
# mitsubishi             -     -       -     -         -  2376.56        -
# nissan                 -     -    2008     -         -     2176  3116.33
# subaru                 -     -       -     -      2240     2085        -
# toyota                 -  2975       -  2585         -  2177.25  2626.83
# volkswagen          2254     -       -     -         -     2221        -
# volvo                  -     -       -     -         -        -        -
# Average             2254  2975    2008  2585      2240     2178  2673.46
#
# body_style     sedan                     wagon                   Average
# drive_wheels     4wd      fwd      rwd     4wd      fwd      rwd
# make
# honda              -   2288.8        -       -     2024        -  2097.0
# mazda              -   2231.6     2685       -        -        -  2298.0
# mitsubishi         -     2394        -       -        -        -  2382.0
# nissan             -  2237.89        -       -  2452.33        -  2400.0
# subaru        2447.5     2225        -    2535   2372.5        -  2316.0
# toyota             -  2258.57  2521.67    2700     2280     3151  2441.0
# volkswagen         -  2342.22        -       -     2563        -  2343.0
# volvo              -        -     3023       -        -  3077.67  3038.0
# Average       2447.5  2282.95  2855.31  2617.5  2371.12     3096  2406.0

# %% [markdown]
# ### Visualizing results with Seaborn

# %%
# Seaborn's heatmap can visualize the final results of the crosstab
sns.heatmap(pd.crosstab(df.drive_wheels, df.make))

# %%
# This is a more complex customization of a heatmap
sns.heatmap(pd.crosstab([df.make, df.num_doors], [df.body_style, df.drive_wheels]), cmap="YlGnBu", 
            annot=True, cbar=False)

# %%
sns.heatmap(pd.crosstab(df.make, df.body_style, values=df.curb_weight, aggfunc='mean').round(0))

# %%
sns.heatmap(pd.crosstab(df.make, [df.body_style, df.drive_wheels], 
            values=df.curb_weight, aggfunc='mean', margins=True, margins_name='Average'),
           cmap="YlGnBu", annot=True, cbar=False, fmt='.0f')
